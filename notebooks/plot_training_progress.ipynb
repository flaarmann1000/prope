# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import numpy as np

# result_path = "nvs/release-1gpus-b8-s1-80k-plucker-none-PERSIST-24k"
# result_path = "nvs/release-1gpus-b8-s1-80k-plucker-none-PERSIST-MSE-ONLY"
# result_path = "nvs_vae/release-1gpus-b8-s1-80k-camray-prope_bias_LinearOutput"
# result_path = "nvs_vae/release-1gpus-b8-s1-80k-camray-prope_A"
# result_path = "nvs_vae/release-1gpus-b8-s1-80k-camray-prope_patchsize1"
result_path = "nvs_vae/release-1gpus-b8-s1-80k-camray-prope"

with open(f"../results/{result_path}/log.txt", "r") as f:
    current_text = f.read()

# Function to parse logs
def parse_log(log_text):    
    pattern = r"Step:\s*(\d+),\s*Loss:\s*([\deE\+\-\.]+|nan),\s*PSNR:\s*([\deE\+\-\.]+),\s*SSIM:\s*([\deE\+\-\.]+),\s*LPIPS:\s*([\deE\+\-\.]+)"
    data = re.findall(pattern, log_text)
    df = pd.DataFrame(data, columns=["Step", "Loss", "PSNR", "SSIM", "LPIPS"]).astype(float)
    return df

# df_4 = parse_log(log_4)
# df_6 = parse_log(log_6)
current_text = parse_log(current_text)

def smooth_data(data, smooth=40):
        kernel_size = smooth * 2 - 1
        kernel = np.ones(kernel_size) / kernel_size
        padded = np.pad(data, (kernel_size//2,), mode='reflect')
        return np.convolve(padded, kernel, mode='valid')

def create_plot(current_text, smooth = 20):

    # Plot
    fig, axs = plt.subplots(4, 1, figsize=(8, 10), sharex=True)

    # PSNR
    # axs[0].plot(df_4["Step"], df_4["PSNR"], label="4 layers", marker="o")
    # axs[0].plot(df_6["Step"], df_6["PSNR"], label="6 layers", marker="o")
    axs[0].plot(current_text["Step"], current_text["PSNR"], label="vae /camray & prope / normalized", marker="", alpha=0.5)
    axs[0].plot(current_text["Step"], smooth_data(current_text["PSNR"], smooth),'b', label="vae /camray & prope / normalized", marker="")
    axs[0].set_ylabel("PSNR")
    axs[0].set_xlabel("Step")
    # axs[0].legend()
    axs[0].grid(True)

    # SSIM
    # axs[1].plot(df_4["Step"], df_4["SSIM"], label="4 layers", marker="o")
    # axs[1].plot(df_6["Step"], df_6["SSIM"], label="6 layers", marker="o")
    axs[1].plot(current_text["Step"], current_text["SSIM"], label="vae /camray & prope / normalized", marker="", alpha=0.5)
    axs[1].plot(current_text["Step"], smooth_data(current_text["SSIM"], smooth),'b', label="vae /camray & prope / normalized", marker="")
    axs[1].set_ylabel("SSIM")
    axs[1].set_xlabel("Step")
    axs[1].grid(True)

    # LPIPS
    # axs[2].plot(df_4["Step"], df_4["LPIPS"], label="4 layers", marker="o")
    # axs[2].plot(df_6["Step"], df_6["LPIPS"], label="6 layers", marker="o")
    # axs[2].set_ylabel("LPIPS")

    # Loss
    loss = current_text["Loss"]

    axs[2].plot(current_text["Step"], loss, label="vae /camray & prope / normalized", marker="")
    axs[2].set_ylabel("Loss")
    axs[2].set_xlabel("Step")
    axs[2].grid(True)

    log_loss = np.log(loss)

    axs[3].plot(current_text["Step"], log_loss, label="vae /camray & prope / normalized", marker="", alpha=0.5)
    axs[3].plot(current_text["Step"], smooth_data(log_loss, smooth), 'b', label="vae /camray & prope / normalized", marker="")    
    axs[3].set_ylabel("log Loss")
    axs[3].set_xlabel("Step")
    axs[3].grid(True)        


    plt.tight_layout()
    plt.show()

create_plot(current_text, 20)

# current_text
